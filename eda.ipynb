# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
LABEL_F = '/home/sharif/Documents/commai-challenge/data/labels/train_with_test_labels.txt'

# %%
labels = open(LABEL_F).readlines()
labels = [float(labels[i].split()[0]) for i in range(len(labels))]
labels = [round(label) for label in labels]
labels = np.array(labels)

# %%
min(labels)
# Out:
# 0

# %%
max(labels)
# Out:
# 28

# %%
plt.plot(labels)
plt.show()

# %%
plt.hist(labels, 29);
